# %%
import re

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 

import pdb

from pathlib import Path
from tqdm import tqdm

# %%
lamah_ce_path = Path("/home/wuhlmann/BA/data/raw_data/2_LamaH-CE_daily")

# %% [markdown]
# #### Confirm integretity for climatic timeseries, hydrologic indices and static attributes.

# %%
B_climatic_timeseries_path = lamah_ce_path / "B_basins_intermediate_all/2_timeseries/daily"
C_climatic_timeseries_path = lamah_ce_path / "C_basins_intermediate_lowimp/2_timeseries/daily"
hydrologic_signatures_path = lamah_ce_path / "D_gauges/1_attributes/Hydro_indices_1981_2017.csv"

B_timeseries_paths = list(sorted(B_climatic_timeseries_path.glob("*.csv")))
C_timeseries_paths = list(sorted(C_climatic_timeseries_path.glob("*.csv")))

# Get IDs of low impact basins. 
C_ids = []
for p in C_timeseries_paths:
    stem = Path(p).stem
    match = re.search(r'\d+', stem)
    if match:
        C_ids.append(int(match.group()))
C_ids = sorted(C_ids)

# %% [markdown]
# Climatic values do not contain any NA, as expected from ERA5 data.

# %%
#for path in tqdm(B_timeseries_paths):

    #ts = pd.read_table(path, sep=";", header=0)

    #if ts.isnull().values.any(): 
        #print(f"Climatic data {path.stem} contains NA")

# %% [markdown]
# 17/9 Basins contain NA in their hydrologic indices, 4/2 of those only at the baseflow indices, if they are not used as predictor, still usable. Discard other 13/7 catchments.

# %%
hydrologic_signatures = pd.read_table(hydrologic_signatures_path, header=0, sep=";")

A_B_basins_with_NA = hydrologic_signatures[hydrologic_signatures.isna().any(axis=1)]

C_hydrologic_signatures = hydrologic_signatures[hydrologic_signatures["ID"].isin(C_ids)]

C_basins_with_NA = C_hydrologic_signatures[C_hydrologic_signatures.isna().any(axis=1)]

display(A_B_basins_with_NA, C_basins_with_NA)
# Out:
#       ID  q_mean  runoff_ratio  stream_elas  slope_fdc  baseflow_index_ladson  \
# 53    55     NaN           NaN          NaN        NaN                    NaN
# 316  319     NaN           NaN          NaN        NaN                    NaN
# 349  352   0.404         0.207        1.559      2.474                    NaN
# 369  376     NaN           NaN          NaN        NaN                    NaN
# 399  407     NaN           NaN          NaN        NaN                    NaN
# 402  410     NaN           NaN          NaN        NaN                    NaN
# 406  414   0.184         0.062        5.272        NaN                  0.331
# 533  551     NaN           NaN          NaN        NaN                    NaN
# 535  553     NaN           NaN          NaN        NaN                    NaN
# 555  573     NaN           NaN          NaN        NaN                    NaN
# 607  625     NaN           NaN          NaN        NaN                    NaN
# ...

# %% [markdown]
# 53 / 21 Basins have one or more missing static attribute. In most cases, this hi_prec_ti, which is the season (3 months, as their capitals) in which the moste P occurs.

# %%
B_static_attributes_path = lamah_ce_path / "B_basins_intermediate_all/1_attributes/Catchment_attributes.csv"
B_static_attributes = pd.read_table(B_static_attributes_path, header=0, sep=";")
B_basins_NA_attr =  B_static_attributes[B_static_attributes.isna().any(axis=1)]

C_static_attributes_path = lamah_ce_path / "C_basins_intermediate_lowimp/1_attributes/Catchment_attributes.csv"
C_static_attributes = pd.read_table(C_static_attributes_path, header=0, sep=";")
C_basins_NA_attr = C_static_attributes[C_static_attributes.isna().any(axis=1)]

display(B_basins_NA_attr, C_basins_NA_attr)
# Out:
#       ID  area_calc  elev_mean  elev_med  elev_std  elev_ran  slope_mean  \
# 7      8     69.361       1562      1610       344      1879         407
# 24    25     14.067       1289      1268       171       841         304
# 31    33     25.443       2077      2079       258      1318         343
# 33    35    163.471       1911      1921       328      1721         395
# 61    63    200.842       1669      1647       577      2423         365
# 62    64    180.302       1288      1144       532      2200         307
# 107  109     47.327       1135      1076       330      1612         376
# 134  136     64.669        971       906       337      1527         307
# 144  147    191.280        853       695       409      1788         229
# 147  150     70.298        466       462        35       177          57
# 159  162     89.814        439       431        47       286          53
# 178  181     44.038        635       635        83       408         131
# ...

# %%
# Set basin id as index of hydrologic signatures and SAC, for easier access. 
hydrologic_signatures.set_index("ID", inplace=True)
B_static_attributes.set_index("ID", inplace=True)

# %%
discharge_path = lamah_ce_path / "D_gauges/2_timeseries/daily"
discharge_path_list = list(sorted(discharge_path.glob("*.csv")))

valid_ids = list(B_static_attributes.index)

basin_ids = []
coverage = []
start_days = []
end_days = []
num_missing_days = []
gap_percentage = []
average_gap_length = []
max_gap_length = []
gap_dates = []
q5_q95_normal_periods = []
z_normal_periods = []


for path in discharge_path_list:

    basin_id = int(re.search(r"\d+", path.stem).group())

    # Some gauge, don't have static catchment attributes. They are not considered. 
    if not basin_id in valid_ids: 
        continue

    basin_ids.append(basin_id)

    discharge = pd.read_table(path, header=0, sep=";")

    # Set index to d
    discharge["date"] = pd.to_datetime(
        discharge[["YYYY", "MM", "DD"]].rename(columns={"YYYY": "year", "MM": "month", "DD": "day"})
        )
    discharge.set_index("date", inplace=True)

    # How many days are NA?
    count_na = (discharge["qobs"] == -999).sum()
    num_missing_days.append(count_na)

    # What percentage of total coverage is that?
    gap_percentage.append(count_na/len(discharge)*100)

    coverage.append(len(discharge))

    # Get start and end dates of coverage for each basins, 
    start_days.append(discharge.index[0])

    end_days.append(discharge.index[-1])
    
    # Prepare tracking of periods between Q5 and Q95. 
    q5 = hydrologic_signatures.loc[basin_id, "Q5"] 
    q95 = hydrologic_signatures.loc[basin_id, "Q95"]

    # Q5 and Q95 are averaged over the area, revert.
    area = B_static_attributes.loc[basin_id, "area_calc"]
    q5 = (q5 * area * 10e6) / (1000* 86400)
    q95 = (q95 * area * 10e6) / (1000 * 86400)
    
    current_normal_period_duration = 0 
    current_normal_period_date_span = [None, None]

    basin_q_normal_periods = []
    
    # Calculate mean and std for z-score. 
    q_mean = discharge["qobs"].mean()
    q_std = discharge["qobs"].std()

    current_z_duration = 0 
    current_z_date_span = [None, None]

    basin_z_normal_periods = []

    # Caculate the length of all gaps. 
    current_gap = 0
    current_date_span = [None, None]

    gap_lengths = []
    start_end_dates = []

    for i in discharge.index: 

        qobs_i = discharge.loc[i, "qobs"]
        
        # Track gaps.
        if not qobs_i == -999: 
            if current_gap > 0:

                # If there was a gap, it's now over, append to all gaps and reset counter.
                gap_lengths.append(current_gap)
                current_gap = 0

                # Also fetch end date, append date range of gap and reset date span.
                current_date = i
                # -1 because the last gap day, is the previous one.
                current_date_span[1] = current_date - pd.Timedelta(days=1)

                start_end_dates.append(current_date_span)
                current_date_span = [None, None]
        else:
            if current_gap == 0: 
                
                # If there is no gap yet, fetch the current date as the start date of the gap. 
                current_date_span[0] = i
                
            current_gap += 1

        z_score = (qobs_i - q_mean) / q_std

        # Track z score normal periods. 
        if abs(z_score) < 2.0: 

            # Z Normal period starts. 
            if current_z_duration == 0: 
                current_z_date_span[0] = i

            current_z_duration += 1

        else: 
            # If there was a normal period, its now over. 
            if current_z_duration > 0: 
                current_z_date_span[1] = i - pd.Timedelta(days=1)
                
                if current_z_duration >= 0: 
                    basin_z_normal_periods.append(current_z_date_span) 
            
            current_z_duration = 0 
            current_z_date_span = [None, None]

        # Track "normal" periods with q5 < qobs < q95. 
        if qobs_i > q5 and qobs_i < q95: 

            # Normal period starts. 
            if current_normal_period_duration == 0: 
                current_normal_period_date_span[0] = i

            current_normal_period_duration += 1
        else: 
            # If there was a normal period, its now over. 
            if current_normal_period_duration > 0: 
                current_normal_period_date_span[1] = i - pd.Timedelta(days=1)
                
                if current_normal_period_duration >= 0:
                    basin_q_normal_periods.append(current_date_span)
            
            current_normal_period_duration = 0 
            current_normal_period_date_span = [None, None]

    if gap_lengths: 
        average_gap_length.append(np.mean(gap_lengths))
        max_gap_length.append(np.max(gap_lengths))
        gap_dates.append(start_end_dates)
    else: 
        average_gap_length.append(0)
        max_gap_length.append(0)
        gap_dates.append([None,None])

    if basin_z_normal_periods:
        z_normal_periods.append(basin_z_normal_periods)
    else:
        z_normal_periods.append([None,None])

    if basin_q_normal_periods:
        q5_q95_normal_periods.append(basin_z_normal_periods)
    else:
        q5_q95_normal_periods.append([None, None])

coverage_stats= pd.DataFrame({
    "basin_id": basin_ids,
    "coverage": coverage,
    "start": start_days,
    "end": end_days,
    "num_missing_days": num_missing_days,
    "percentage [%]": gap_percentage,
    "avg_gap": average_gap_length,
    "max_gap": max_gap_length,
    "gap_dates": gap_dates,
    "q5_q95_normal_periods" : q5_q95_normal_periods,
    "z_normal_periods" : z_normal_periods
})

# %%
coverage_stats_sorted = coverage_stats.sort_values("basin_id")
coverage_stats_sorted.set_index("basin_id", inplace=True)

# %%
num_normal_z_periods = 0
num_normal_z_days = 0

num_normal_q_periods = 0
num_normal_q_days = 0

for basin in coverage_stats_sorted.index: 

    if not coverage_stats_sorted.loc[basin,"z_normal_periods"] == [None, None]: 
        num_normal_z_periods += len(coverage_stats_sorted.loc[basin,"z_normal_periods"])

        for period in coverage_stats_sorted.loc[basin, "z_normal_periods"]: 
            start = period[0]
            end = period[1]

            delta = end - start 
            
            if delta.days >= 14: 
                num_normal_z_days += delta.days

    if not coverage_stats_sorted.loc[basin, "q5_q95_normal_periods"] == [None, None]: 
        num_normal_q_periods += len(coverage_stats_sorted.loc[basin, "q5_q95_normal_periods"])

        for period in coverage_stats_sorted.loc[basin, "q5_q95_normal_periods"]:
            start = period[0]
            end = period[1]

            delta = end - start 

            if delta.days >= 30: 
                num_normal_q_days += delta.days

# %%
np.mean(list(map(lambda x: len(x),coverage_stats_sorted["q5_q95_normal_periods"])))
# Out:
# 134.54132712456345

# %%
num_normal_q_days
# Out:
# 8835074

# %%
coverage_stats_sorted = coverage_stats.sort_values("basin_id")
coverage_stats_sorted.set_index("basin_id", inplace=True)

processed_data_path = Path("/home/wuhlmann/BA/data/processed_data")
coverage_stats_sorted.to_csv(
    processed_data_path / "eda/discharge_coverage.csv",
    sep=";")

# %% [markdown]
# Imputation only makes sense up until a certain gap length (the chosen one is 7/14), all basins with longer gaps are either tossed or the timeseries before or after the gap (depending on what is longer, is used).
#
# Basins 129 misses the last two days, therefore the gap "never ends" and the gap range remains empty.

# %%
basins_with_missing_discharge = coverage_stats_sorted[coverage_stats_sorted["percentage [%]"]>0]

basins_critical_gap_length = basins_with_missing_discharge[basins_with_missing_discharge["max_gap"]>1]

# %%
import matplotlib.pyplot as plt

# Daten vorbereiten und sortieren
missing_stats_sorted = basins_critical_gap_length.sort_values("start")
basin_ids_sorted = missing_stats_sorted.index.astype(str)

# Plot
fig, ax = plt.subplots(figsize=(10, len(basin_ids_sorted) * 0.25))

# Hintergrund: Gesamte Datenabdeckung
ax.barh(
    y=basin_ids_sorted,
    width=missing_stats_sorted["end"] - missing_stats_sorted["start"],
    left=missing_stats_sorted["start"],
    height=0.8,
    color="skyblue",
    edgecolor="k"
)

# Lücken: Gaps als rote Balken
for i, basin_id in enumerate(basin_ids_sorted):

    gap_dates = missing_stats_sorted.loc[int(basin_id),"gap_dates"]

    color = "red" if len(gap_dates) != 1 else "yellow"    

    for gap_start, gap_end in gap_dates:
        ax.barh(
            y=basin_id,
            width=(gap_end - gap_start)*10,
            left=gap_start,
            height=0.8,
            color="red",
            alpha=0.5
        )



ax.set_xlabel("Datum")
ax.set_ylabel("Basin ID")
ax.set_title("Zeitliche Abdeckung + Datenlücken in EZG mit Lücken > 14 ")
plt.tight_layout()
plt.show()
