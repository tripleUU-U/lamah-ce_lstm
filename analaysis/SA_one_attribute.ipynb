# %%
from pathlib import Path

import torch 

from neuralhydrology.datasetzoo import get_dataset
from neuralhydrology.evaluation import get_tester
from neuralhydrology.datautils.utils import load_scaler
from neuralhydrology.modelzoo.ealstm import EALSTM
from neuralhydrology.utils.config import Config

# %%
torch.cuda.get_device_name()
# Out:
# 'NVIDIA A100-PCIE-40GB'

# %%
# Load the config.
run_dir_path = Path("/home/wuhlmann/BA/test_runs/runs/test_256_1024_1811_133845")
cfg = Config(run_dir_path / "config.yml")

# %%
# Load the final model configuration.
ea_lstm = EALSTM(cfg=cfg)
final_weigthts = torch.load(str(run_dir_path / "model_epoch030.pt"), map_location="cpu")
ea_lstm.load_state_dict(final_weigthts)
# Out:
# <All keys matched successfully>

# %%
# Load dataset (for now just test (later combine all sets)).
scaler = load_scaler(run_dir=run_dir_path)
ds = get_dataset(cfg=cfg, is_train=True, period="train", scaler=scaler)
# Out:
# 100%|██████████| 669/669 [00:01<00:00, 338.82it/s]
# 100%|██████████| 669/669 [00:33<00:00, 20.04it/s]

# %%
#attribute one. 
tester = get_tester(cfg=cfg, run_dir=run_dir_path, period="validation", init_model=True)

# %%
(10  * 30 * 10 )/ 60  / 4
# Out:
# 12.5

# %%
for basin_id in tester.cached_datasets.keys():

    print(tester.cached_datasets[basin_id]._attributes[basin_id][0])
# Out:
# tensor(0.8730)
# tensor(-0.9969)
# tensor(-1.2074)
# tensor(-0.7474)
# tensor(1.0652)
# tensor(0.4688)
# tensor(1.8410)
# tensor(2.2074)
# tensor(0.1180)
# tensor(-1.3789)
# tensor(-1.2893)
# tensor(-1.3789)
# tensor(-1.1879)
# tensor(0.5195)
# tensor(-0.5018)
# tensor(0.7105)
# tensor(-0.7669)
# tensor(-0.0613)
# tensor(-0.1978)
# tensor(-1.3010)
# tensor(-0.2913)
# tensor(0.9366)
# tensor(-1.1762)
# tensor(0.7495)
# tensor(1.3459)
# tensor(1.8059)
# tensor(-0.9813)
# tensor(0.3051)
# tensor(1.0457)
# tensor(0.6832)
# tensor(0.5351)
# tensor(0.5234)
# tensor(1.0457)
# tensor(-0.6656)
# tensor(0.6208)
# tensor(0.6364)
# tensor(-0.0107)
# tensor(-0.4473)
# tensor(-0.4667)
# tensor(0.5234)
# tensor(-1.1022)
# tensor(-1.0866)
# tensor(-1.2074)
# tensor(-1.1996)
# tensor(-0.6188)
# tensor(0.6014)
# tensor(0.9834)
# tensor(1.2173)
# tensor(-1.2230)
# tensor(0.2388)
# tensor(-0.3420)
# tensor(-0.4706)
# tensor(0.1414)
# tensor(0.0205)
# tensor(0.7222)
# tensor(-1.2659)
# tensor(1.2056)
# tensor(-1.1294)
# tensor(-0.9579)
# tensor(1.0691)
# tensor(-0.9852)
# tensor(0.8157)
# tensor(0.9561)
# tensor(-0.8955)
# tensor(0.6325)
# tensor(1.1471)
# tensor(0.5390)
# tensor(0.6286)
# tensor(1.3810)
# tensor(-1.0203)
# tensor(0.1453)
# tensor(-1.3438)
# tensor(0.2661)
# tensor(-0.5915)
# tensor(0.5117)
# tensor(1.0730)
# tensor(0.9834)
# tensor(1.9774)
# tensor(1.0379)
# tensor(-0.8410)
# tensor(-0.0263)
# tensor(1.1159)
# tensor(-0.2601)
# tensor(-0.3342)
# tensor(-1.3750)

# %%
tester.cached_datasets["123"]._load_combined_attributes()
